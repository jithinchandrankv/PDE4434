# %%
from tensorflow.keras.models import load_model
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
#from tensorflow.keras.applications.vgg19 import preprocess_input
import numpy as np
import cv2

# %%
model=load_model("uno number1-cnn.h5")

# %%
path="images"
i=0

for img in os.listdir(path):
    img=image.load_img(path+"/"+img,target_size=(224,224))
    plt.imshow(img)
    plt.show()
    
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)
    print(x.shape)
    images=np.vstack([x])
    pred=model.predict(images,batch_size=0)
    
    nameList = ['1', '2', '3', '4', '5', '6', '7', '8', '9', 'Draw 2', 'Reverese', 'Wild card', 'Wild card draw 4', 'skip'] 
    pVal = max(pred[0])
    print(pVal)
    
    maxIndex = 0
    for i in pred[0]:
        if i==pVal:
            break
        maxIndex+=1
    
    print(nameList[maxIndex])
# Out:
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 61ms/step
# 5.5493956
# 2
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 58ms/step
# 17.969486
# Wild card draw 4
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 42ms/step
# 15.826563
# Wild card draw 4
